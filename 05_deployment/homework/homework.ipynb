# %% [markdown]
# ### Question 1: What's the version of uv you installed?

# %%
import uv

# %%
# !uv --version
# Out:
# uv 0.9.5 (d5f39331a 2025-10-21)

# %% [markdown]
# ### Question 2:
#
# - You should create an empty folder for homework and do it there: <code>uv init </code>
# - Use uv to install Scikit-Learn version 1.6.1: <code>uv add scikit-learn</code>
# - What's the first hash for Scikit-Learn you get in the lock file?
# - Include the entire string starting with sha256:, don't include quotes
#
# <code>sha256:20e9e49ecd130598f1ca38a1d85090e1a600147b9c02fa6f15d69cb53d968fda<code>

# %% [markdown]
# ### Download saved model

# %%
# !wget "https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin"
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
